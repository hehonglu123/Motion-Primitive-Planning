# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
curve_forward = pd.read_csv('train_data/curve1/forward/base/curve_51.csv', header=None).values
curve_reverse = pd.read_csv('train_data/curve1/reverse/base/curve_10.csv', header=None).values
curve_forward.shape, curve_reverse.shape
# Out:
# ((5000, 6), (5000, 6))

# %%
fig, ax = plt.subplots(subplot_kw={"projection": '3d'})
ax.plot3D(curve_forward[:, 0], curve_forward[:, 1], curve_forward[:, 2], 'r.-')
ax.plot3D(curve_reverse[:, 0], curve_reverse[:, 1], curve_reverse[:, 2], 'b.-')
plt.show()

# %%
fig, ax = plt.subplots(subplot_kw={"projection": '3d'})
for i in range(10):
    curve = pd.read_csv('train_data/curve1/forward/base/curve_{}.csv'.format(i), header=None).values
    ax.plot3D(curve[:, 0], curve[:, 1], curve[:, 2]')
